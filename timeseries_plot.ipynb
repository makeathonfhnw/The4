# %%
import pandas as pd
import plotly as py
import plotly.graph_objs as go
import plotly.io as pio
import plotly.express as px
import numpy as np
import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from plotly.subplots import make_subplots

# %%
df_twitter = pd.read_csv('data\german_tweets_sentimental_analysed.csv')
df_appstores = pd.read_csv('data/app_play_trainset.csv')
df_appstores = df_appstores[df_appstores['language_prob'] == 'de']

# %%
data = pd.read_csv('data\play_store.csv')

# %%
df_powerpoint = df_twitter[['content', 'language_prob', 'Positive', 'Negative', 'Neutral']]

# %%
df_twitter_positive = df_twitter[df_twitter['Positive'] > 0.8]
df_twitter_negative = df_twitter[df_twitter['Negative'] > 0.8]
df_twitter_neutral = df_twitter[df_twitter['Neutral'] > 0.8]

# %%
df_appstores_positive = df_appstores[df_appstores['Positive'] > 0.8]  
df_appstores_negative = df_appstores[df_appstores['Negative'] > 0.8]
df_appstores_neutral = df_appstores[df_appstores['Neutral'] > 0.8]

# %%
df_twitter
# Out:
#                            date  \
# 0     2022-10-01 09:15:01+00:00
# 1     2022-09-30 19:56:59+00:00
# 2     2022-09-30 19:54:18+00:00
# 3     2022-09-30 19:45:11+00:00
# 4     2022-09-30 19:44:10+00:00
# ...                         ...
# 6066  2009-03-13 20:18:15+00:00
# 6067  2009-01-26 10:37:35+00:00
# 6068  2008-12-18 22:18:10+00:00
# 6069  2008-12-05 10:40:44+00:00
# 6070  2008-09-18 09:44:46+00:00
#
#                                                 content language_prob  \
# 0     Habe diese Woche meine Fail-Kreditkarte bei @P...            de
# 1     @pbruegger @JuereVoBaern @twintapp @PostFinanc...            de
# 2     @WohlgensingerN @JuereVoBaern @twintapp @PostF...            de
# 3     @pbruegger @JuereVoBaern @twintapp @PostFinanc...            de
# 4     @pbruegger @twintapp @PostFinance Also sgkb Tw...            de
# ...                                                 ...           ...
# 6066  @hediger haha, das ist der running gag 2.0. se...            de
# 6067  #Postfinance hat es geschaft die Namen aller b...            de
# 6068  Wie wär's mit einer Yellownet App? #tweetback ...            de
# 6069  Post-Umsatzgarant: Für einfache administrative...            de
# 6070  ...och, noch immer kein iPhone! #postfinance.c...            de
#
#       Positive  Negative   Neutral
# 0     0.044578  0.955002  0.000420
# 1     0.008653  0.983254  0.008093
# 2     0.006538  0.993362  0.000100
# 3     0.025193  0.974599  0.000208
# 4     0.014871  0.969653  0.015477
# ...        ...       ...       ...
# 6066  0.019020  0.980770  0.000210
# 6067  0.003521  0.996301  0.000177
# 6068  0.048990  0.933976  0.017034
# 6069  0.004724  0.977397  0.017880
# 6070  0.005579  0.994371  0.000049
#
# [6071 rows x 6 columns]

# %%
#plot df_twitter_negative and df_appstores_negative on y and time on x
fig = make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing=0.03,
                    subplot_titles=("Twitter", "Appstores"))

fig.add_trace(go.Scatter(x=df_twitter_negative['date'], y=df_twitter_negative['Positive'], name='Twitter Negative'), row=1, col=1)
fig.add_trace(go.Scatter(x=df_appstores_negative['date'], y=df_appstores_negative['Positive'], name='Appstores Negative'), row=2, col=1)

# %%
#Tweet Example
tweet =  df_powerpoint['content'][11]
rating = df_powerpoint['Negative'][11]
print(' TWEET:',tweet, '--> NEGATIVE RATING  :', rating )
# Out:
#  TWEET: @PostFinance Liebe @PostFinance jetzt geht ihr aber ab oder? Könnt ihr nicht noch einen 1 Beinigen kleinwüchsigen Inuit in der Werbung aufnehmen, der fehlt noch bei eurem Diversity Müll der den Kunden zugemutet wird. Danke --> NEGATIVE RATING  : 0.9412947
